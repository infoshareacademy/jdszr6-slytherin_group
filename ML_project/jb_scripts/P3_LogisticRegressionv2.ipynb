# %%
import pandas as pd
import seaborn as sns
import numpy as np
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
file_path="/Users/joannaborowa/Desktop/WA_Fn-UseC_-Telco-Customer-Churn.csv"
df=pd.read_csv(file_path)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.groupby(by=["gender"]).count()["customerID"]
# Out:
# gender
# Female    3488
# Male      3555
# Name: customerID, dtype: int64

# %%
df.groupby(by=["SeniorCitizen"]).count()["customerID"]
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: customerID, dtype: int64

# %%
df.groupby(by=["Partner"]).count()["customerID"]
# Out:
# Partner
# No     3641
# Yes    3402
# Name: customerID, dtype: int64

# %%
df.groupby(by=["Dependents"]).count()["customerID"]
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: customerID, dtype: int64

# %%
df.groupby(by=["tenure"]).count()["customerID"]
# Out:
# tenure
# 0      11
# 1     613
# 2     238
# 3     200
# 4     176
#      ...
# 68    100
# 69     95
# 70    119
# 71    170
# 72    362
# Name: customerID, Length: 73, dtype: int64

# %%
df.groupby(by=["PhoneService"]).count()["customerID"]
# Out:
# PhoneService
# No      682
# Yes    6361
# Name: customerID, dtype: int64

# %%
df.groupby(by=["MultipleLines"]).count()["customerID"]
# Out:
# MultipleLines
# No                  3390
# No phone service     682
# Yes                 2971
# Name: customerID, dtype: int64

# %%
df.groupby(by=["InternetService"]).count()["customerID"]
# Out:
# InternetService
# DSL            2421
# Fiber optic    3096
# No             1526
# Name: customerID, dtype: int64

# %%
df.groupby(by=["OnlineSecurity"]).count()["customerID"]
# Out:
# OnlineSecurity
# No                     3498
# No internet service    1526
# Yes                    2019
# Name: customerID, dtype: int64

# %%
df.groupby(by=["DeviceProtection"]).count()["customerID"]
# Out:
# DeviceProtection
# No                     3095
# No internet service    1526
# Yes                    2422
# Name: customerID, dtype: int64

# %%
df.groupby(by=["TechSupport"]).count()["customerID"]
# Out:
# TechSupport
# No                     3473
# No internet service    1526
# Yes                    2044
# Name: customerID, dtype: int64

# %%
df.groupby(by=["StreamingTV"]).count()["customerID"]
# Out:
# StreamingTV
# No                     2810
# No internet service    1526
# Yes                    2707
# Name: customerID, dtype: int64

# %%
df.groupby(by=["StreamingMovies"]).count()["customerID"]
# Out:
# StreamingMovies
# No                     2785
# No internet service    1526
# Yes                    2732
# Name: customerID, dtype: int64

# %%
df.groupby(by=["Contract"]).count()["customerID"]
# Out:
# Contract
# Month-to-month    3875
# One year          1473
# Two year          1695
# Name: customerID, dtype: int64

# %%
df.groupby(by=["PaperlessBilling"]).count()["customerID"]
# Out:
# PaperlessBilling
# No     2872
# Yes    4171
# Name: customerID, dtype: int64

# %%
df.groupby(by=["PaymentMethod"]).count()["customerID"]
# Out:
# PaymentMethod
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Electronic check             2365
# Mailed check                 1612
# Name: customerID, dtype: int64

# %%
df.groupby(by=["Churn"]).count()["customerID"]
# Out:
# Churn
# No     5174
# Yes    1869
# Name: customerID, dtype: int64

# %%
df.groupby(by=["OnlineBackup"]).count()["customerID"]
# Out:
# OnlineBackup
# No                     3088
# No internet service    1526
# Yes                    2429
# Name: customerID, dtype: int64

# %%
df["OnlineBackup"].isnull().count()
# Out:
# 7043

# %%
df.groupby(by=["TotalCharges"]).count()["customerID"]
# Out:
# TotalCharges
#           11
# 100.2      1
# 100.25     1
# 100.35     1
# 100.4      1
#           ..
# 997.75     1
# 998.1      1
# 999.45     1
# 999.8      1
# 999.9      1
# Name: customerID, Length: 6531, dtype: int64

# %%
df.drop(df[df['TotalCharges'] == " "].index, inplace = True)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
partner_r=(df["Partner"]=="Yes") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[partner_r]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 2804  6158-DWPZT   Male              0     Yes         No       9
# 5631  6542-LWGXJ   Male              0     Yes         No       3
# 6509  0616-ATFGB   Male              1     Yes         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 2804           No  No phone service             DSL             No  ...
# 5631           No  No phone service             DSL             No  ...
# 6509           No  No phone service             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 2804               No          No          No              No        One year
# 5631               No          No          No              No  Month-to-month
# 6509               No          No          No              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# ...

# %%
dependent_r=(df["Partner"]=="No") & (df["Dependents"]=="Yes") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[dependent_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1944  0420-BWTPW    Male              0      No        Yes       8
# 2046  2538-OIMXF  Female              0      No        Yes       1
# 4424  4729-XKASR    Male              0      No        Yes       1
# 5489  0804-XBFBV  Female              0      No        Yes      11
# 6979  5351-QESIO    Male              0      No        Yes       1
# 6984  6447-GORXK    Male              0      No        Yes      31
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1944           No  No phone service             DSL             No  ...
# 2046           No  No phone service             DSL             No  ...
# 4424           No  No phone service             DSL             No  ...
# 5489           No  No phone service             DSL             No  ...
# 6979           No  No phone service             DSL             No  ...
# ...

# %%
phoneservice_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="Yes") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[phoneservice_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 34    3413-BMNZE    Male              1      No         No       1
# 134   2372-HWUHI    Male              0      No         No       2
# 181   6582-OIVSP  Female              0      No         No       1
# 204   9142-KZXOP    Male              0      No         No      44
# 274   5940-AHUHD    Male              0      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 6718  8676-TRMJS    Male              0      No         No       3
# 6726  0685-MLYYM  Female              1      No         No       2
# 6877  4501-EQDRN  Female              0      No         No       1
# 6896  3085-QUOZK  Female              0      No         No       1
# 6907  1041-RXHRA  Female              0      No         No      41
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 34            Yes            No             DSL             No  ...
# ...

# %%
OnlineSecurity_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="Yes") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[OnlineSecurity_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7     6713-OKOMC  Female              0      No         No      10
# 107   9750-BOOHV  Female              0      No         No      32
# 116   9560-BBZXK  Female              0      No         No      36
# 2712  5133-VRSAB    Male              0      No         No       8
# 3902  5999-LCXAO  Female              0      No         No       1
# 4099  6624-JDRDS  Female              0      No         No       6
# 6080  9526-BIHHD    Male              0      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7              No  No phone service             DSL            Yes  ...
# 107            No  No phone service             DSL            Yes  ...
# 116            No  No phone service             DSL            Yes  ...
# 2712           No  No phone service             DSL            Yes  ...
# ...

# %%
OnlineBackup_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="Yes") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[OnlineBackup_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 180   6317-YPKDH  Female              0      No         No       1
# 498   6235-VDHOM  Female              1      No         No       5
# 688   0946-FKYTX    Male              0      No         No      52
# 3042  1322-AGOQM    Male              0      No         No      46
# 3492  0975-VOOVL  Female              0      No         No       3
# 6677  1442-BQPVU  Female              0      No         No      13
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 180            No  No phone service             DSL             No  ...
# 498            No  No phone service             DSL             No  ...
# 688            No  No phone service             DSL             No  ...
# 3042           No  No phone service             DSL             No  ...
# 3492           No  No phone service             DSL             No  ...
# ...

# %%
DeviceProtection_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="Yes") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[DeviceProtection_r]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 3318  5016-ETTFF   Male              0      No         No      10
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 3318           No  No phone service             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 3318              Yes          No          No              No  Month-to-month
#
#      PaperlessBilling PaymentMethod MonthlyCharges  TotalCharges Churn
# 3318               No  Mailed check           29.5        255.25   Yes
#
# [1 rows x 21 columns]

# %%
TechSupport_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="Yes") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[TechSupport_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 187   8167-GJLRN    Male              0      No         No       3
# 1637  4999-IEZLT    Male              0      No         No      66
# 3139  1142-WACZW    Male              0      No         No       2
# 3677  6656-JWRQX  Female              0      No         No       1
# 3753  1816-FLZDK    Male              0      No         No       1
# 4174  3285-UCQVC  Female              0      No         No      37
# 5387  8676-OOQEJ    Male              0      No         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 187            No  No phone service             DSL             No  ...
# 1637           No  No phone service             DSL             No  ...
# 3139           No  No phone service             DSL             No  ...
# 3677           No  No phone service             DSL             No  ...
# ...

# %%
StreamingTV_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="Yes") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="No")  
df[StreamingTV_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3905  5759-RCVCB  Female              0      No         No       3
# 4765  8727-XDPUD    Male              0      No         No      37
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 3905           No  No phone service             DSL             No  ...
# 4765           No  No phone service             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 3905               No          No         Yes              No  Month-to-month
# 4765               No          No         Yes              No        Two year
#
#      PaperlessBilling            PaymentMethod MonthlyCharges  TotalCharges  \
# 3905               No  Credit card (automatic)           35.2        108.95
# 4765               No  Credit card (automatic)           35.8        1316.9
#
#      Churn
# 3905   Yes
# 4765    No
#
# [2 rows x 21 columns]

# %%
StreamingMovies_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="Yes")& (df["PaperlessBilling"]=="No")  
df[StreamingMovies_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1257  0723-VSOBE  Female              1      No         No      45
# 2427  7854-FOKSF    Male              0      No         No       1
# 6256  3751-KTZEL  Female              0      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1257           No  No phone service             DSL             No  ...
# 2427           No  No phone service             DSL             No  ...
# 6256           No  No phone service             DSL             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 1257               No          No          No             Yes        One year
# 2427               No          No          No             Yes  Month-to-month
# 6256               No          No          No             Yes  Month-to-month
#
#      PaperlessBilling     PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
PaperlessBilling_r=(df["Partner"]=="No") & (df["Dependents"]=="No") & (df["PhoneService"]=="No") & (df["OnlineSecurity"]=="No") & (df["OnlineBackup"]=="No") & (df["DeviceProtection"]=="No") & (df["TechSupport"]=="No") & (df["StreamingTV"]=="No") & (df["StreamingMovies"]=="No")& (df["PaperlessBilling"]=="Yes")  
df[PaperlessBilling_r]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 616   6464-KEXXH    Male              0      No         No       8
# 660   5650-VDUDS  Female              0      No         No       4
# 1221  3055-MJDSB    Male              0      No         No       9
# 1331  7537-RBWEA  Female              0      No         No       1
# 1334  1768-ZAIFU  Female              1      No         No       1
# 1513  0661-XEYAN  Female              1      No         No       1
# 2295  2672-DZUOY    Male              0      No         No       1
# 2431  8263-JQAIK    Male              1      No         No       2
# 3092  6032-IGALN  Female              0      No         No       1
# 3150  6029-CSMJE    Male              0      No         No      17
# 3258  7365-BVCJH    Male              0      No         No       1
# 3505  1335-NTIUC    Male              0      No         No       9
# 3756  9136-ALYBR    Male              0      No         No       1
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import pandas as pd
import seaborn as sns
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.utils import shuffle
from statsmodels.formula.api import ols
import numpy as np
from IPython.display import Image
import lxml

# %%
x=df["tenure"]
y=df["MonthlyCharges"]
plt.scatter(x,y)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# Logistic regression

# %%
# Looping through all the features by our y variable - see if there is relationship

features = ['gender','SeniorCitizen', 'Partner',
       'Dependents', 'tenure',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract',
            'PaperlessBilling','PaymentMethod',]

for f in features:
    sns.countplot(x = f, data = df, palette = 'Set3', hue = 'Churn')
    plt.show()

# %%
# Making categorical variables into numeric representation

new_df = pd.get_dummies(df, columns = features)

# Notes:
# We can also do this with Label Encoding and OneHotEncoder from the preprocessing library

print(df.shape)
# print the shape
print(new_df.shape)

# Creating a new 0-1 y variable
#new_raw_data['Loan Approved2'] = 0
new_df['Churn'][new_df['Churn'] == 'Yes'] = 1
new_df['Churn'][new_df['Churn'] == 'No'] = 0

# Visualizing the data
new_df
# Out:
# (7032, 21)
# (7032, 119)
# /var/folders/7h/_q8280k96s9cyp_l8vczlx340000gn/T/ipykernel_85519/1973732969.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Churn'][new_df['Churn'] == 'Yes'] = 1
# /var/folders/7h/_q8280k96s9cyp_l8vczlx340000gn/T/ipykernel_85519/1973732969.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Churn'][new_df['Churn'] == 'No'] = 0
#       customerID  MonthlyCharges TotalCharges Churn  gender_Female  \
# 0     7590-VHVEG           29.85        29.85     0              1
# 1     5575-GNVDE           56.95       1889.5     0              0
# ...

# %%
X= new_df.drop(["customerID"],axis=1).values

# %%
y=new_df["Churn"].values

# %%
y=y.astype('int')

# %%
print(X.shape)
print(y.shape)
# Out:
# (7032, 118)
# (7032,)

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, explained_variance_score, confusion_matrix, accuracy_score, classification_report, log_loss
from math import sqrt

# %%
# Run a Tree-based estimators (i.e. decision trees & random forests)

dt = DecisionTreeClassifier(random_state=44, criterion = 'entropy', max_depth = 10)
dt.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, random_state=44)

# %%
# Running Feature Importance

fi_col = []
fi = []

for i,column in enumerate(df.drop('Churn', axis = 1)):
    print('The feature importance for {} is : {}'.format(column, dt.feature_importances_[i]))
    
    fi_col.append(column)
    fi.append(dt.feature_importances_[i])
# Out:
# The feature importance for customerID is : 0.0
# The feature importance for gender is : 0.0
# The feature importance for SeniorCitizen is : 1.0
# The feature importance for Partner is : 0.0
# The feature importance for Dependents is : 0.0
# The feature importance for tenure is : 0.0
# The feature importance for PhoneService is : 0.0
# The feature importance for MultipleLines is : 0.0
# The feature importance for InternetService is : 0.0
# The feature importance for OnlineSecurity is : 0.0
# The feature importance for OnlineBackup is : 0.0
# The feature importance for DeviceProtection is : 0.0
# The feature importance for TechSupport is : 0.0
# The feature importance for StreamingTV is : 0.0
# The feature importance for StreamingMovies is : 0.0
# The feature importance for Contract is : 0.0
# The feature importance for PaperlessBilling is : 0.0
# The feature importance for PaymentMethod is : 0.0
# The feature importance for MonthlyCharges is : 0.0
# ...

# %%
# Creating a Dataframe
fi_col
fi

fi_df = zip(fi_col, fi)
fi_df = pd.DataFrame(fi_df, columns = ['Feature','Feature Importance'])
fi_df


# Ordering the data
fi_df = fi_df.sort_values('Feature Importance', ascending = False).reset_index()

# Creating columns to keep
columns_to_keep = fi_df['Feature'][0:120]

fi_df
# Out:
#     index           Feature  Feature Importance
# 0       2     SeniorCitizen                 1.0
# 1       0        customerID                 0.0
# 2      11  DeviceProtection                 0.0
# 3      18    MonthlyCharges                 0.0
# 4      17     PaymentMethod                 0.0
# 5      16  PaperlessBilling                 0.0
# 6      15          Contract                 0.0
# 7      14   StreamingMovies                 0.0
# 8      13       StreamingTV                 0.0
# 9      12       TechSupport                 0.0
# 10     10      OnlineBackup                 0.0
# 11      1            gender                 0.0
# 12      9    OnlineSecurity                 0.0
# 13      8   InternetService                 0.0
# 14      7     MultipleLines                 0.0
# 15      6      PhoneService                 0.0
# 16      5            tenure                 0.0
# 17      4        Dependents                 0.0
# 18      3           Partner                 0.0
# ...

# %%
# Hold-out validation

# first one
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.6, test_size=0.4, random_state=44)

# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=44)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (3797, 118)
# (2813, 118)
# (422, 118)
# (3797,)
# (2813,)
# (422,)

# %%
# Investigating the distr of all ys

ax = sns.countplot(x = y_valid, palette = "Set3")

# %%
# Training my model

log_reg = LogisticRegression(random_state=44, solver = 'lbfgs')

log_reg.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=44)

# %%
# Methods we can use in Logistic

# predict - Predict class labels for samples in X
log_reg.predict(X_train)
y_pred = log_reg.predict(X_train)

# predict_proba - Probability estimates
pred_proba = log_reg.predict_proba(X_train)

# coef_ - Coefficient of the features in the decision function
log_reg.coef_

# score- Returns the mean accuracy on the given test data and labels - below
# Out:
# array([[-2.73036674e-02, -2.08318500e-06,  9.81661967e+00,
#         -2.73858085e-01, -3.74216121e-01, -3.91991369e-01,
#         -2.56082837e-01, -3.61600619e-01, -2.86473587e-01,
#         -3.13516894e-01, -3.34557312e-01,  1.02732447e+00,
#          9.42923480e-02, -3.51212017e-02,  1.24273554e-01,
#          1.08607514e-01, -5.53511305e-02, -4.92763418e-02,
#         -9.52206980e-02, -1.47142127e-02,  9.65574161e-03,
#         -1.14830083e-01, -2.54777441e-03, -1.04112412e-01,
#         -4.32554398e-02,  2.30096174e-02, -3.91215646e-03,
#         -1.11490242e-01, -1.19921246e-01, -1.03605515e-01,
#         -6.84504147e-02, -4.30089546e-02, -2.77985437e-02,
#         -1.14471465e-01, -9.69621080e-02,  5.06416909e-02,
#         -1.32862752e-01, -5.79983737e-02, -2.33415955e-02,
#         -9.49071865e-02, -4.36993127e-02, -6.43220462e-02,
#         -3.67913711e-02,  2.93566667e-02, -9.91764488e-02,
#         -6.06300190e-02, -4.98495673e-02, -2.73627156e-02,
# ...

# %%
# Accuracy on Train
print("The Training Accuracy is: ", log_reg.score(X_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", log_reg.score(X_test, y_test))


# Classification Report
print(classification_report(y_train, y_pred))
# Out:
# The Training Accuracy is:  1.0
# The Testing Accuracy is:  1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2803
#            1       1.00      1.00      1.00       994
#
#     accuracy                           1.00      3797
#    macro avg       1.00      1.00      1.00      3797
# weighted avg       1.00      1.00      1.00      3797

# %%
# Confusion Matrix function

def plot_confusion_matrix(cm, classes=None, title='Confusion matrix'):
    """Plots a confusion matrix."""
    if classes is not None:
        sns.heatmap(cm, cmap="YlGnBu", xticklabels=classes, yticklabels=classes, vmin=0., vmax=1., annot=True, annot_kws={'size':50})
    else:
        sns.heatmap(cm, vmin=0., vmax=1.)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Visualizing cm

cm = confusion_matrix(y_train, y_pred)
cm_norm = cm / cm.sum(axis=1).reshape(-1,1)

plot_confusion_matrix(cm_norm, classes = log_reg.classes_, title='Confusion matrix')

# %%
log_reg.classes_
# Out:
# array([0, 1])

# %%
cm.sum(axis=1)
cm_norm
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
cm
# Out:
# array([[2803,    0],
#        [   0,  994]])

# %%
cm.sum(axis=0)
# Out:
# array([2803,  994])

# %%
np.diag(cm)
# Out:
# array([2803,  994])

# %%
# Calculating False Positives (FP), False Negatives (FN), True Positives (TP) & True Negatives (TN)

FP = cm.sum(axis=0) - np.diag(cm)
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)


# Sensitivity, hit rate, recall, or true positive rate
TPR = TP / (TP + FN)
print("The True Positive Rate is:", TPR)

# Precision or positive predictive value
PPV = TP / (TP + FP)
print("The Precision is:", PPV)

# False positive rate or False alarm rate
FPR = FP / (FP + TN)
print("The False positive rate is:", FPR)


# False negative rate or Miss Rate
FNR = FN / (FN + TP)
print("The False Negative Rate is: ", FNR)



##Total averages :
print("")
print("The average TPR is:", TPR.sum()/2)
print("The average Precision is:", PPV.sum()/2)
print("The average False positive rate is:", FPR.sum()/2)
print("The average False Negative Rate is:", FNR.sum()/2)
# Out:
# The True Positive Rate is: [1. 1.]
# The Precision is: [1. 1.]
# The False positive rate is: [0. 0.]
# The False Negative Rate is:  [0. 0.]
#
# The average TPR is: 1.0
# The average Precision is: 1.0
# The average False positive rate is: 0.0
# The average False Negative Rate is: 0.0

# %%
# Running Log loss on training
print("The Log Loss on Training is: ", log_loss(y_train, pred_proba))

# Running Log loss on testing
pred_proba_t = log_reg.predict_proba(X_test)
print("The Log Loss on Testing Dataset is: ", log_loss(y_test, pred_proba_t))
# Out:
# The Log Loss on Training is:  0.005895078857174688
# The Log Loss on Testing Dataset is:  0.0059399903492637724

# %% [markdown]
# Parameter tuning

# %%
np.geomspace(1e-5, 1e5, num=20)
# Out:
# array([1.00000000e-05, 3.35981829e-05, 1.12883789e-04, 3.79269019e-04,
#        1.27427499e-03, 4.28133240e-03, 1.43844989e-02, 4.83293024e-02,
#        1.62377674e-01, 5.45559478e-01, 1.83298071e+00, 6.15848211e+00,
#        2.06913808e+01, 6.95192796e+01, 2.33572147e+02, 7.84759970e+02,
#        2.63665090e+03, 8.85866790e+03, 2.97635144e+04, 1.00000000e+05])

# %%
# Creating a range for C values
np.geomspace(1e-5, 1e5, num=20)

# ploting it
plt.plot(np.geomspace(1e-5, 1e5, num=20)) #  uniformly distributed in log space
plt.plot(np.linspace(1e-5, 1e5, num=20)) # uniformly distributed in linear space, instead of log space
# plt.plot(np.logspace(np.log10(1e-5) , np.log10(1e5) , num=20)) # same as geomspace

# %%
# Looping over the parameters

C_List = np.geomspace(1e-5, 1e5, num=20)
CA = []
Logarithmic_Loss = []

for c in C_List:
    log_reg2 = LogisticRegression(random_state=44, solver = 'lbfgs', C=c)
    log_reg2.fit(X_train, y_train)
    score = log_reg2.score(X_test, y_test)
    CA.append(score)
    print("The CA of C parameter {} is {}:".format(c, score))
    pred_proba_t = log_reg2.predict_proba(X_test)
    log_loss2 = log_loss(y_test, pred_proba_t)
    Logarithmic_Loss.append(log_loss2)
    print("The Logg Loss of C parameter {} is {}:".format(c, log_loss2))
    print("")
# Out:
# The CA of C parameter 1e-05 is 0.7923924635620334:
# The Logg Loss of C parameter 1e-05 is 0.47640620483909757:
#
# The CA of C parameter 3.359818286283781e-05 is 0.7899040170636331:
# The Logg Loss of C parameter 3.359818286283781e-05 is 0.46893656659896993:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# The CA of C parameter 0.00011288378916846884 is 0.7948809100604337:
# The Logg Loss of C parameter 0.00011288378916846884 is 0.4586511017863526:
# ...

# %%
# putting the outcomes in a Table

# reshaping
CA2 = np.array(CA).reshape(20,)
Logarithmic_Loss2 = np.array(Logarithmic_Loss).reshape(20,)

# zip
outcomes = zip(C_List, CA2, Logarithmic_Loss2)

#df
df_outcomes = pd.DataFrame(outcomes, columns = ["C_List", 'CA2','Logarithmic_Loss2'])

#print
df_outcomes

# Ordering the data (sort_values)
df_outcomes.sort_values("Logarithmic_Loss2", ascending = True).reset_index()
# Out:
#     index         C_List       CA2  Logarithmic_Loss2
# 0      19  100000.000000  1.000000           0.000002
# 1      18   29763.514416  1.000000           0.000005
# 2      16    2636.650899  1.000000           0.000005
# 3      17    8858.667904  1.000000           0.000020
# 4      14     233.572147  1.000000           0.000061
# 5      15     784.759970  1.000000           0.000160
# 6      13      69.519280  1.000000           0.000174
# 7      12      20.691381  1.000000           0.000494
# 8      11       6.158482  1.000000           0.001198
# 9      10       1.832981  1.000000           0.003816
# 10      9       0.545559  1.000000           0.009613
# 11      8       0.162378  1.000000           0.022872
# 12      7       0.048329  0.998578           0.059721
# 13      6       0.014384  0.990402           0.132241
# 14      5       0.004281  0.948098           0.242869
# 15      4       0.001274  0.897263           0.349831
# ...

# %%
# Another way of doing the above
# Scikit-learn offers a LogisticRegressionCV module which implements Logistic Regression 
# with builtin cross-validation to find out the optimal C parameter

from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import KFold
kf = KFold(n_splits=3, random_state=44, shuffle=True)

# Logistic Reg CV
Log_reg3 = LogisticRegressionCV(random_state=44, Cs = C_List, solver ='lbfgs')
Log_reg3.fit(X_train, y_train)
print("The CA is:", Log_reg3.score(X_test, y_test))
pred_proba_t = Log_reg3.predict_proba(X_test)
log_loss3 = log_loss(y_test, pred_proba_t)
print("The Logistic Loss is: ", log_loss3)

print("The optimal C parameter is: ", Log_reg3.C_)



# Doc: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegressionCV.html
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Maybe we have a different metric we want to track

# Looping over the parameters

C_List = np.geomspace(1e-5, 1e5, num=20)
CA = []
Logarithmic_Loss = []

for c in C_List:
    log_reg2 = LogisticRegression(random_state=44, solver = 'lbfgs', C=c)
    log_reg2.fit(X_train, y_train)
    score = log_reg2.score(X_test, y_test)
    CA.append(score)
    print("The CA of C parameter {} is {}:".format(c, score))
    pred_proba_t = log_reg2.predict_proba(X_test)
    log_loss2 = log_loss(y_test, pred_proba_t)
    Logarithmic_Loss.append(log_loss2)
    print("The Logg Loss of C parameter {} is {}:".format(c, log_loss2))
    print("")
    
    y_pred = log_reg2.predict(X_train)
    cm = confusion_matrix(y_train, y_pred)
    cm_norm = cm / cm.sum(axis=1).reshape(-1,1)
    plot_confusion_matrix(cm_norm, classes = log_reg.classes_, title='Confusion matrix')
    plt.show()
# Out:
# The CA of C parameter 1e-05 is 0.7923924635620334:
# The Logg Loss of C parameter 1e-05 is 0.47640620483909757:
# The CA of C parameter 3.359818286283781e-05 is 0.7899040170636331:
# The Logg Loss of C parameter 3.359818286283781e-05 is 0.46893656659896993:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# The CA of C parameter 0.00011288378916846884 is 0.7948809100604337:
# The Logg Loss of C parameter 0.00011288378916846884 is 0.4586511017863526:
# ...

# %%
# Training a Dummy Classifier

from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(X_train, y_train)
score = dummy_clf.score(X_test, y_test)

pred_proba_t = dummy_clf.predict_proba(X_test)
log_loss2 = log_loss(y_test, pred_proba_t)

print("Testing Acc:", score)
print("Log Loss:", log_loss2)


# Doc: https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html
# Out:
# Testing Acc: 0.7326697476004266
# Log Loss: 9.2332598112239

# %% [markdown]
# Final Model with Selected Parameters

# %%
# Final Model 

log_reg3 = LogisticRegression(random_state=44, solver = 'lbfgs', C=29763.51441631313)
log_reg3.fit(X_train, y_train)
score = log_reg3.score(X_valid, y_valid)

pred_proba_t = log_reg3.predict_proba(X_valid)
log_loss2 = log_loss(y_valid, pred_proba_t)

print("Testing Acc:", score)
print("Log Loss:", log_loss2)
# Out:
# Testing Acc: 1.0
# Log Loss: 8.94344127178885e-06
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Accuracy on Train
print("The Training Accuracy is: ", log_reg.score(X_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", log_reg.score(X_test, y_test))


# Classification Report
print(classification_report(y_train, y_pred))
# Out:
# The Training Accuracy is:  1.0
# The Testing Accuracy is:  1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2803
#            1       1.00      1.00      1.00       994
#
#     accuracy                           1.00      3797
#    macro avg       1.00      1.00      1.00      3797
# weighted avg       1.00      1.00      1.00      3797

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
l_probs = [0 for _ in range(len(y_test))]
lg_probs = log_reg3.predict_proba(X_test)

# %%
lg_probs = lg_probs[:, 1]

# %%
l_auc = roc_auc_score(y_test, l_probs)
lg_auc = roc_auc_score(y_test, lg_probs)

# %%
print('Random (chance) Prediction: AUROC = %.3f' % (l_auc))
print('Logistic regression: AUROC = %.3f' % (lg_auc))
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Logistic regression: AUROC = 1.000

# %%
l_fpr, l_tpr, _ = roc_curve(y_test, l_probs)
lg_fpr, lg_tpr, _ = roc_curve(y_test, lg_probs)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(l_fpr, l_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % l_auc)
plt.plot(lg_fpr, lg_tpr, marker='.', label='Logistic regression (AUROC = %0.3f)' % lg_auc)

# Title
plt.title('ROC Plot')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.show()

# %% [markdown]
# GreadSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }
]

# %%
clf = GridSearchCV(log_reg, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)

# %%
best_clf = clf.fit(X,y)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# ...

# %%
best_clf.best_estimator_
# Out:
# LogisticRegression(C=0.0001, penalty='none', random_state=44)

# %%
log_reg4 = LogisticRegression(random_state=44, solver = 'lbfgs', C=29763.51441631313)
log_reg4.fit(X_train, y_train)
score = log_reg4.score(X_valid, y_valid)

pred_proba_t = log_reg4.predict_proba(X_valid)
log_loss2 = log_loss(y_valid, pred_proba_t)

print("Testing Acc:", score)
print("Log Loss:", log_loss2)
# Accuracy on Train
print("The Training Accuracy is: ", log_reg.score(X_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", log_reg.score(X_test, y_test))


# Classification Report
print(classification_report(y_train, y_pred))
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Testing Acc: 1.0
# Log Loss: 8.94344127178885e-06
# The Training Accuracy is:  1.0
# The Testing Accuracy is:  1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2803
#            1       1.00      1.00      1.00       994
#
#     accuracy                           1.00      3797
#    macro avg       1.00      1.00      1.00      3797
# weighted avg       1.00      1.00      1.00      3797
