# %%
import cv2
import os

# %%
letter="Y"
# !mkdir={letter}

# %%
cam = cv2.VideoCapture(0)

path="{}".format(letter)

# %%
img_counter = 0

while True:
    ret, frame = cam.read()
    if not ret:
        print("failed to grab frame")
        break
        
    height, width, channels = frame.shape
    height, width = height // 10, width // 10

    if height > width:
        main_size = width
    else:
        main_size = height

    square_box = [(width, width + 5*main_size), (height, height + 5*main_size)]
    roi = frame[square_box[1][0] : square_box[1][1], square_box[0][0] : square_box[0][1]]
    
    cv2.imshow("Press space to grab picture, press Esc to exit", roi)
    #cv2.imshow(" ", frame)

    k = cv2.waitKey(1)
    if k%256 == 27:
        # ESC pressed
        print("Escape hit, closing...")
        break
    elif k%256 == 32:
        # SPACE pressed 
        img_name = os.path.join(path, 'pic_{}.png'.format(img_counter))
        # resized = cv2.resize(frame, (300,300), interpolation = cv2.INTER_AREA)
        cv2.imwrite(img_name, roi)
        print("{} written!".format(img_name))
        img_counter += 1

cam.release()
cv2.destroyAllWindows()
# Out:
# Y\pic_0.png written!
# Y\pic_1.png written!
# Y\pic_2.png written!
# Y\pic_3.png written!
# Y\pic_4.png written!
# Y\pic_5.png written!
# Y\pic_6.png written!
# Y\pic_7.png written!
# Y\pic_8.png written!
# Y\pic_9.png written!
# Y\pic_10.png written!
# Y\pic_11.png written!
# Y\pic_12.png written!
# Y\pic_13.png written!
# Y\pic_14.png written!
# Y\pic_15.png written!
# Y\pic_16.png written!
# Y\pic_17.png written!
# Y\pic_18.png written!
# Y\pic_19.png written!
# Y\pic_20.png written!
# Y\pic_21.png written!
# Y\pic_22.png written!
# Y\pic_23.png written!
# Y\pic_24.png written!
# Y\pic_25.png written!
# Y\pic_26.png written!
# Y\pic_27.png written!
# Y\pic_28.png written!
# Y\pic_29.png written!
# Y\pic_30.png written!
# Y\pic_31.png written!
# Y\pic_32.png written!
# Y\pic_33.png written!
# Y\pic_34.png written!
# Y\pic_35.png written!
# Y\pic_36.png written!
# Y\pic_37.png written!
# Y\pic_38.png written!
# Y\pic_39.png written!
# Y\pic_40.png written!
# Y\pic_41.png written!
# Y\pic_42.png written!
# Y\pic_43.png written!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [53], in <cell line: 4>()
#       1 img_counter = 0
#       3 while True:
# ----> 4     ret, frame = cam.read()
#       5     if not ret:
#       6         print("failed to grab frame")
#
# KeyboardInterrupt:
