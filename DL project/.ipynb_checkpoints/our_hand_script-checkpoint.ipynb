# %%
import os 
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from numpy import asarray

# %%
my_path=os.getcwd()
image_folder='all'
target_path=os.path.join(my_path, image_folder)

# %%
target_path
# Out:
# 'c:\\Users\\Lenovo\\Desktop\\Szkolenie\\jdszr6-slytherin_group\\DL project\\all'

# %%
tf.keras.preprocessing.image_dataset_from_directory(
    target_path,
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(28, 28),
    shuffle=True,
    seed=44,
    validation_split=0.3,
    subset="training",
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    #**kwarags
)
# Out:
# Found 22164 files belonging to 24 classes.
# Using 15515 files for training.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    target_path,
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(28, 28),
    shuffle=True,
    seed=44,
    validation_split=0.3,
    subset="training",
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    #**kwarags
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    target_path,
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(28, 28),
    shuffle=True,
    seed=44,
    validation_split=0.3,
    subset="validation",
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False,
    #**kwarags
)
# Out:
# Found 22164 files belonging to 24 classes.
# Using 15515 files for training.
# Found 22164 files belonging to 24 classes.
# Using 6649 files for validation.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i])#.numpy().astypa("unit8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        augmented_image = data_augmentation(images)
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
from PIL import Image
import numpy as np

# %%
img_data = np.random.random(size=(28, 28, 1))
img = tf.keras.preprocessing.image.array_to_img(img_data)
array = tf.keras.preprocessing.image.img_to_array(img)

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %%
# Define  & train the model without regularization
model1 = tf.keras.models.Sequential([
                                                         
  # Add convolutions and max pooling
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28,1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),

  # Add the same layers as before
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.1),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(25, activation='softmax')
])

# Print the model summary
model1.summary()

# Use same settings
model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
print(f'\nMODEL TRAINING & VALIDATION:')

history1= model1.fit(
  train_ds, epochs=30, validation_data=val_ds
)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  random_flip_4 (RandomFlip)  (None, 5, 5, 32)          0
#
#  random_rotation_4 (RandomRo  (None, 5, 5, 32)         0
#  tation)
#
#  flatten_1 (Flatten)         (None, 800)               0
#
#  dense_2 (Dense)             (None, 128)               102528
#
#  dense_3 (Dense)             (None, 25)                3225
#
# =================================================================
# Total params: 115,321
# Trainable params: 115,321
# Non-trainable params: 0
# _________________________________________________________________
#
# MODEL TRAINING & VALIDATION:
# Epoch 1/30
# 485/485 [==============================] - 59s 119ms/step - loss: 3.2924 - accuracy: 0.1203 - val_loss: 2.4872 - val_accuracy: 0.2507
# Epoch 2/30
# 485/485 [==============================] - 34s 70ms/step - loss: 2.3139 - accuracy: 0.3024 - val_loss: 1.7724 - val_accuracy: 0.4489
# Epoch 3/30
# 485/485 [==============================] - 34s 70ms/step - loss: 1.7381 - accuracy: 0.4637 - val_loss: 1.4066 - val_accuracy: 0.5640
# Epoch 4/30
# 485/485 [==============================] - 35s 72ms/step - loss: 1.2979 - accuracy: 0.5932 - val_loss: 1.1380 - val_accuracy: 0.6487
# Epoch 5/30
# 485/485 [==============================] - 33s 67ms/step - loss: 1.0387 - accuracy: 0.6719 - val_loss: 0.8861 - val_accuracy: 0.7194
# Epoch 6/30
# 485/485 [==============================] - 35s 72ms/step - loss: 0.8048 - accuracy: 0.7451 - val_loss: 0.7689 - val_accuracy: 0.7579
# Epoch 7/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.6992 - accuracy: 0.7763 - val_loss: 0.6105 - val_accuracy: 0.8037
# Epoch 8/30
# 485/485 [==============================] - 37s 75ms/step - loss: 0.5852 - accuracy: 0.8142 - val_loss: 0.5508 - val_accuracy: 0.8252
# Epoch 9/30
# 485/485 [==============================] - 37s 75ms/step - loss: 0.5386 - accuracy: 0.8268 - val_loss: 0.5722 - val_accuracy: 0.8233
# Epoch 10/30
# 485/485 [==============================] - 36s 73ms/step - loss: 0.4876 - accuracy: 0.8425 - val_loss: 0.4718 - val_accuracy: 0.8525
# Epoch 11/30
# 485/485 [==============================] - 37s 75ms/step - loss: 0.4492 - accuracy: 0.8571 - val_loss: 0.4986 - val_accuracy: 0.8513
# Epoch 12/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.3877 - accuracy: 0.8732 - val_loss: 0.4921 - val_accuracy: 0.8588
# Epoch 13/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.3810 - accuracy: 0.8750 - val_loss: 0.5362 - val_accuracy: 0.8458
# Epoch 14/30
# 485/485 [==============================] - 35s 72ms/step - loss: 0.3751 - accuracy: 0.8779 - val_loss: 0.4036 - val_accuracy: 0.8761
# Epoch 15/30
# 485/485 [==============================] - 35s 72ms/step - loss: 0.3353 - accuracy: 0.8926 - val_loss: 0.3770 - val_accuracy: 0.8926
# Epoch 16/30
# 485/485 [==============================] - 36s 73ms/step - loss: 0.3272 - accuracy: 0.8953 - val_loss: 0.3584 - val_accuracy: 0.8874
# Epoch 17/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.2798 - accuracy: 0.9074 - val_loss: 0.4229 - val_accuracy: 0.8860
# Epoch 18/30
# 485/485 [==============================] - 36s 73ms/step - loss: 0.2933 - accuracy: 0.9024 - val_loss: 0.3580 - val_accuracy: 0.8929
# Epoch 19/30
# 485/485 [==============================] - 38s 77ms/step - loss: 0.2699 - accuracy: 0.9100 - val_loss: 0.5392 - val_accuracy: 0.8469
# Epoch 20/30
# 485/485 [==============================] - 38s 78ms/step - loss: 0.2714 - accuracy: 0.9119 - val_loss: 0.3412 - val_accuracy: 0.9101
# Epoch 21/30
# 485/485 [==============================] - 38s 77ms/step - loss: 0.2683 - accuracy: 0.9144 - val_loss: 0.3639 - val_accuracy: 0.8968
# Epoch 22/30
# 485/485 [==============================] - 38s 77ms/step - loss: 0.2504 - accuracy: 0.9200 - val_loss: 0.3585 - val_accuracy: 0.9063
# Epoch 23/30
# 485/485 [==============================] - 38s 78ms/step - loss: 0.2637 - accuracy: 0.9143 - val_loss: 0.3513 - val_accuracy: 0.9015
# Epoch 24/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.2435 - accuracy: 0.9215 - val_loss: 0.3850 - val_accuracy: 0.9004
# Epoch 25/30
# 485/485 [==============================] - 37s 75ms/step - loss: 0.2365 - accuracy: 0.9248 - val_loss: 0.3675 - val_accuracy: 0.8989
# Epoch 26/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.2414 - accuracy: 0.9212 - val_loss: 0.3402 - val_accuracy: 0.9093
# Epoch 27/30
# 485/485 [==============================] - 36s 73ms/step - loss: 0.2226 - accuracy: 0.9299 - val_loss: 0.3910 - val_accuracy: 0.9027
# Epoch 28/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.2254 - accuracy: 0.9302 - val_loss: 0.4678 - val_accuracy: 0.8869
# Epoch 29/30
# 485/485 [==============================] - 36s 74ms/step - loss: 0.2308 - accuracy: 0.9258 - val_loss: 0.5004 - val_accuracy: 0.8747
# Epoch 30/30
# 485/485 [==============================] - 36s 73ms/step - loss: 0.2206 - accuracy: 0.9321 - val_loss: 0.4956 - val_accuracy: 0.8803

# %%
model1.save('model.h5')

# %%
import cv2

# %%
img = cv2.imread("all\A\pic_dm (20).png")
img_gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_res = cv2.resize(img_gray, (28,28))
plt.imshow(img_res)
plt.show()

print('model prediciton:',model1.predict(img_res.reshape(1,28,28,1),verbose=0).argmax())
# Out:
# model prediciton: 0
