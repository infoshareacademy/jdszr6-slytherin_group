# %%
import pandas as pd
import numpy as np

# %%
file_path="/Users/joannaborowa/Desktop/good_bad_clients.csv"
df=pd.read_csv(file_path)
df
# Out:
#        Unnamed: 0       ID  NUMBER_OF_RECORDS  ACTIVE  TOTAL_STATUS  GOOD_BAD
# 0               0  5001711                  4       1     -0.300000         0
# 1               4  5001712                 19       1      0.565789         1
# 2              23  5001713                 22       1      0.000000         1
# 3              45  5001714                 15       1      0.000000         1
# 4              60  5001715                 60       1      0.000000         1
# ...           ...      ...                ...     ...           ...       ...
# 45980     1048494  5150482                 18       0      0.315789         1
# 45981     1048512  5150483                 18       1      0.000000         1
# 45982     1048530  5150484                 13       1     -0.285714         0
# 45983     1048543  5150485                  2       1      0.000000         1
# 45984     1048545  5150487                 30       1      1.000000         1
#
# [45985 rows x 6 columns]

# %%
file_path="/Users/joannaborowa/Desktop/all_data.csv"
all_data=pd.read_csv(file_path)
all_data
# Out:
#         Unnamed: 0       ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                0  5008804           M             1                1
# 1                1  5008804           M             1                1
# 2                2  5008804           M             1                1
# 3                3  5008804           M             1                1
# 4                4  5008804           M             1                1
# ...            ...      ...         ...           ...              ...
# 777710      777710  5150337           M             0                1
# 777711      777711  5150337           M             0                1
# 777712      777712  5150337           M             0                1
# 777713      777713  5150337           M             0                1
# 777714      777714  5150337           M             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0          427500.0          Working
# 1                  0          427500.0          Working
# 2                  0          427500.0          Working
# 3                  0          427500.0          Working
# 4                  0          427500.0          Working
# ...              ...               ...              ...
# 777710             0          112500.0          Working
# 777711             0          112500.0          Working
# 777712             0          112500.0          Working
# 777713             0          112500.0          Working
# 777714             0          112500.0          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS NAME_HOUSING_TYPE  \
# 0                    Higher education        Civil marriage  Rented apartment
# 1                    Higher education        Civil marriage  Rented apartment
# 2                    Higher education        Civil marriage  Rented apartment
# 3                    Higher education        Civil marriage  Rented apartment
# 4                    Higher education        Civil marriage  Rented apartment
# ...                               ...                   ...               ...
# 777710  Secondary / secondary special  Single / not married  Rented apartment
# 777711  Secondary / secondary special  Single / not married  Rented apartment
# 777712  Secondary / secondary special  Single / not married  Rented apartment
# 777713  Secondary / secondary special  Single / not married  Rented apartment
# 777714  Secondary / secondary special  Single / not married  Rented apartment
#
#         DAYS_BIRTH  DAYS_EMPLOYED  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 0           -12005          -4542                1           0           0
# 1           -12005          -4542                1           0           0
# 2           -12005          -4542                1           0           0
# 3           -12005          -4542                1           0           0
# 4           -12005          -4542                1           0           0
# ...            ...            ...              ...         ...         ...
# 777710       -9188          -1193                0           0           0
# 777711       -9188          -1193                0           0           0
# 777712       -9188          -1193                0           0           0
# 777713       -9188          -1193                0           0           0
# 777714       -9188          -1193                0           0           0
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0         Not provided                2               0      C
# 1         Not provided                2              -1      C
# 2         Not provided                2              -2      C
# 3         Not provided                2              -3      C
# 4         Not provided                2              -4      C
# ...                ...              ...             ...    ...
# 777710        Laborers                1              -9      0
# 777711        Laborers                1             -10      2
# 777712        Laborers                1             -11      1
# 777713        Laborers                1             -12      0
# 777714        Laborers                1             -13      0
#
# [777715 rows x 20 columns]

# %%
new_file=pd.merge(all_data,df,on="ID",how="inner")

# %%
new_file
# Out:
#         Unnamed: 0_x       ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                  0  5008804           M             1                1
# 1                  1  5008804           M             1                1
# 2                  2  5008804           M             1                1
# 3                  3  5008804           M             1                1
# 4                  4  5008804           M             1                1
# ...              ...      ...         ...           ...              ...
# 777710        777710  5150337           M             0                1
# 777711        777711  5150337           M             0                1
# 777712        777712  5150337           M             0                1
# 777713        777713  5150337           M             0                1
# 777714        777714  5150337           M             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0          427500.0          Working
# 1                  0          427500.0          Working
# 2                  0          427500.0          Working
# 3                  0          427500.0          Working
# 4                  0          427500.0          Working
# ...              ...               ...              ...
# 777710             0          112500.0          Working
# 777711             0          112500.0          Working
# 777712             0          112500.0          Working
# 777713             0          112500.0          Working
# 777714             0          112500.0          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ... FLAG_EMAIL  \
# 0                    Higher education        Civil marriage  ...          0
# 1                    Higher education        Civil marriage  ...          0
# 2                    Higher education        Civil marriage  ...          0
# 3                    Higher education        Civil marriage  ...          0
# 4                    Higher education        Civil marriage  ...          0
# ...                               ...                   ...  ...        ...
# 777710  Secondary / secondary special  Single / not married  ...          0
# 777711  Secondary / secondary special  Single / not married  ...          0
# 777712  Secondary / secondary special  Single / not married  ...          0
# 777713  Secondary / secondary special  Single / not married  ...          0
# 777714  Secondary / secondary special  Single / not married  ...          0
#
#         OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  STATUS  \
# 0          Not provided                2               0       C
# 1          Not provided                2              -1       C
# 2          Not provided                2              -2       C
# 3          Not provided                2              -3       C
# 4          Not provided                2              -4       C
# ...                 ...              ...             ...     ...
# 777710         Laborers                1              -9       0
# 777711         Laborers                1             -10       2
# 777712         Laborers                1             -11       1
# 777713         Laborers                1             -12       0
# 777714         Laborers                1             -13       0
#
#         Unnamed: 0_y NUMBER_OF_RECORDS  ACTIVE  TOTAL_STATUS GOOD_BAD
# 0              92938                16       1      0.931985        1
# 1              92938                16       1      0.931985        1
# 2              92938                16       1      0.931985        1
# 3              92938                16       1      0.931985        1
# 4              92938                16       1      0.931985        1
# ...              ...               ...     ...           ...      ...
# 777710       1047002                14       1     -0.521429        0
# 777711       1047002                14       1     -0.521429        0
# 777712       1047002                14       1     -0.521429        0
# 777713       1047002                14       1     -0.521429        0
# 777714       1047002                14       1     -0.521429        0
#
# [777715 rows x 25 columns]

# %% [markdown]
# grouping cnt_children

# %%
conditions=[
    (new_file["CNT_CHILDREN"] == 0),
    (new_file["CNT_CHILDREN"] == 1),
    (new_file["CNT_CHILDREN"] == 2) & (new_file["CNT_CHILDREN"] ==3 ),
    (new_file["CNT_CHILDREN"] >3)
]

# %%
values=["No children", "1 child", "2-3 children", "Many children"]

# %%
new_file["CNT_CHILDREN_CATEGORIZED"]=np.select(conditions,values)
new_file
# Out:
#         Unnamed: 0_x       ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                  0  5008804           M             1                1
# 1                  1  5008804           M             1                1
# 2                  2  5008804           M             1                1
# 3                  3  5008804           M             1                1
# 4                  4  5008804           M             1                1
# ...              ...      ...         ...           ...              ...
# 777710        777710  5150337           M             0                1
# 777711        777711  5150337           M             0                1
# 777712        777712  5150337           M             0                1
# 777713        777713  5150337           M             0                1
# 777714        777714  5150337           M             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0          427500.0          Working
# 1                  0          427500.0          Working
# 2                  0          427500.0          Working
# 3                  0          427500.0          Working
# 4                  0          427500.0          Working
# ...              ...               ...              ...
# 777710             0          112500.0          Working
# 777711             0          112500.0          Working
# 777712             0          112500.0          Working
# 777713             0          112500.0          Working
# 777714             0          112500.0          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ...  \
# 0                    Higher education        Civil marriage  ...
# 1                    Higher education        Civil marriage  ...
# 2                    Higher education        Civil marriage  ...
# 3                    Higher education        Civil marriage  ...
# 4                    Higher education        Civil marriage  ...
# ...                               ...                   ...  ...
# 777710  Secondary / secondary special  Single / not married  ...
# 777711  Secondary / secondary special  Single / not married  ...
# 777712  Secondary / secondary special  Single / not married  ...
# 777713  Secondary / secondary special  Single / not married  ...
# 777714  Secondary / secondary special  Single / not married  ...
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  STATUS  Unnamed: 0_y  \
# 0         Not provided                2               0       C         92938
# 1         Not provided                2              -1       C         92938
# 2         Not provided                2              -2       C         92938
# 3         Not provided                2              -3       C         92938
# 4         Not provided                2              -4       C         92938
# ...                ...              ...             ...     ...           ...
# 777710        Laborers                1              -9       0       1047002
# 777711        Laborers                1             -10       2       1047002
# 777712        Laborers                1             -11       1       1047002
# 777713        Laborers                1             -12       0       1047002
# 777714        Laborers                1             -13       0       1047002
#
#         NUMBER_OF_RECORDS ACTIVE  TOTAL_STATUS  GOOD_BAD  \
# 0                      16      1      0.931985         1
# 1                      16      1      0.931985         1
# 2                      16      1      0.931985         1
# 3                      16      1      0.931985         1
# 4                      16      1      0.931985         1
# ...                   ...    ...           ...       ...
# 777710                 14      1     -0.521429         0
# 777711                 14      1     -0.521429         0
# 777712                 14      1     -0.521429         0
# 777713                 14      1     -0.521429         0
# 777714                 14      1     -0.521429         0
#
#        CNT_CHILDREN_CATEGORIZED
# 0                   No children
# 1                   No children
# 2                   No children
# 3                   No children
# 4                   No children
# ...                         ...
# 777710              No children
# 777711              No children
# 777712              No children
# 777713              No children
# 777714              No children
#
# [777715 rows x 26 columns]

# %% [markdown]
# grouping cnt_family

# %%
conditions1=[
    (new_file["CNT_FAM_MEMBERS"] == 1),
    (new_file["CNT_FAM_MEMBERS"] == 2),
    (new_file["CNT_FAM_MEMBERS"] == 3),
    (new_file["CNT_FAM_MEMBERS"] == 4),
    (new_file["CNT_FAM_MEMBERS"] >4)
]

# %%
values1=["1 person household", "couple", "2+1", "2+2","big family"]

# %%
new_file["CNT_FAM_MEMBERS_CATEGORIZED"]=np.select(conditions1,values1)
new_file
# Out:
#         Unnamed: 0_x       ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                  0  5008804           M             1                1
# 1                  1  5008804           M             1                1
# 2                  2  5008804           M             1                1
# 3                  3  5008804           M             1                1
# 4                  4  5008804           M             1                1
# ...              ...      ...         ...           ...              ...
# 777710        777710  5150337           M             0                1
# 777711        777711  5150337           M             0                1
# 777712        777712  5150337           M             0                1
# 777713        777713  5150337           M             0                1
# 777714        777714  5150337           M             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0          427500.0          Working
# 1                  0          427500.0          Working
# 2                  0          427500.0          Working
# 3                  0          427500.0          Working
# 4                  0          427500.0          Working
# ...              ...               ...              ...
# 777710             0          112500.0          Working
# 777711             0          112500.0          Working
# 777712             0          112500.0          Working
# 777713             0          112500.0          Working
# 777714             0          112500.0          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ...  \
# 0                    Higher education        Civil marriage  ...
# 1                    Higher education        Civil marriage  ...
# 2                    Higher education        Civil marriage  ...
# 3                    Higher education        Civil marriage  ...
# 4                    Higher education        Civil marriage  ...
# ...                               ...                   ...  ...
# 777710  Secondary / secondary special  Single / not married  ...
# 777711  Secondary / secondary special  Single / not married  ...
# 777712  Secondary / secondary special  Single / not married  ...
# 777713  Secondary / secondary special  Single / not married  ...
# 777714  Secondary / secondary special  Single / not married  ...
#
#        CNT_FAM_MEMBERS  MONTHS_BALANCE  STATUS  Unnamed: 0_y  \
# 0                    2               0       C         92938
# 1                    2              -1       C         92938
# 2                    2              -2       C         92938
# 3                    2              -3       C         92938
# 4                    2              -4       C         92938
# ...                ...             ...     ...           ...
# 777710               1              -9       0       1047002
# 777711               1             -10       2       1047002
# 777712               1             -11       1       1047002
# 777713               1             -12       0       1047002
# 777714               1             -13       0       1047002
#
#         NUMBER_OF_RECORDS  ACTIVE TOTAL_STATUS  GOOD_BAD  \
# 0                      16       1     0.931985         1
# 1                      16       1     0.931985         1
# 2                      16       1     0.931985         1
# 3                      16       1     0.931985         1
# 4                      16       1     0.931985         1
# ...                   ...     ...          ...       ...
# 777710                 14       1    -0.521429         0
# 777711                 14       1    -0.521429         0
# 777712                 14       1    -0.521429         0
# 777713                 14       1    -0.521429         0
# 777714                 14       1    -0.521429         0
#
#         CNT_CHILDREN_CATEGORIZED CNT_FAM_MEMBERS_CATEGORIZED
# 0                    No children                      couple
# 1                    No children                      couple
# 2                    No children                      couple
# 3                    No children                      couple
# 4                    No children                      couple
# ...                          ...                         ...
# 777710               No children          1 person household
# 777711               No children          1 person household
# 777712               No children          1 person household
# 777713               No children          1 person household
# 777714               No children          1 person household
#
# [777715 rows x 27 columns]

# %% [markdown]
# grouping amt_income_total

# %%
conditions2=[
    (new_file["AMT_INCOME_TOTAL"] <= 50000),
    (new_file["AMT_INCOME_TOTAL"] > 50000)&(new_file["AMT_INCOME_TOTAL"]<=100000),
    (new_file["AMT_INCOME_TOTAL"] > 100000)& (new_file["AMT_INCOME_TOTAL"]<=200000),
    (new_file["AMT_INCOME_TOTAL"] > 200000),
]

# %%
values2=["very low income", "medium income", "high income", "very high income"]

# %%
new_file["AMT_INCOME_TOTAL_CATEGORIZED"]=np.select(conditions2,values2)
new_file
# Out:
#         Unnamed: 0_x       ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                  0  5008804           M             1                1
# 1                  1  5008804           M             1                1
# 2                  2  5008804           M             1                1
# 3                  3  5008804           M             1                1
# 4                  4  5008804           M             1                1
# ...              ...      ...         ...           ...              ...
# 777710        777710  5150337           M             0                1
# 777711        777711  5150337           M             0                1
# 777712        777712  5150337           M             0                1
# 777713        777713  5150337           M             0                1
# 777714        777714  5150337           M             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0          427500.0          Working
# 1                  0          427500.0          Working
# 2                  0          427500.0          Working
# 3                  0          427500.0          Working
# 4                  0          427500.0          Working
# ...              ...               ...              ...
# 777710             0          112500.0          Working
# 777711             0          112500.0          Working
# 777712             0          112500.0          Working
# 777713             0          112500.0          Working
# 777714             0          112500.0          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ...  \
# 0                    Higher education        Civil marriage  ...
# 1                    Higher education        Civil marriage  ...
# 2                    Higher education        Civil marriage  ...
# 3                    Higher education        Civil marriage  ...
# 4                    Higher education        Civil marriage  ...
# ...                               ...                   ...  ...
# 777710  Secondary / secondary special  Single / not married  ...
# 777711  Secondary / secondary special  Single / not married  ...
# 777712  Secondary / secondary special  Single / not married  ...
# 777713  Secondary / secondary special  Single / not married  ...
# 777714  Secondary / secondary special  Single / not married  ...
#
#        MONTHS_BALANCE  STATUS  Unnamed: 0_y  NUMBER_OF_RECORDS  ACTIVE  \
# 0                   0       C         92938                 16       1
# 1                  -1       C         92938                 16       1
# 2                  -2       C         92938                 16       1
# 3                  -3       C         92938                 16       1
# 4                  -4       C         92938                 16       1
# ...               ...     ...           ...                ...     ...
# 777710             -9       0       1047002                 14       1
# 777711            -10       2       1047002                 14       1
# 777712            -11       1       1047002                 14       1
# 777713            -12       0       1047002                 14       1
# 777714            -13       0       1047002                 14       1
#
#         TOTAL_STATUS GOOD_BAD  CNT_CHILDREN_CATEGORIZED  \
# 0           0.931985        1               No children
# 1           0.931985        1               No children
# 2           0.931985        1               No children
# 3           0.931985        1               No children
# 4           0.931985        1               No children
# ...              ...      ...                       ...
# 777710     -0.521429        0               No children
# 777711     -0.521429        0               No children
# 777712     -0.521429        0               No children
# 777713     -0.521429        0               No children
# 777714     -0.521429        0               No children
#
#         CNT_FAM_MEMBERS_CATEGORIZED AMT_INCOME_TOTAL_CATEGORIZED
# 0                            couple             very high income
# 1                            couple             very high income
# 2                            couple             very high income
# 3                            couple             very high income
# 4                            couple             very high income
# ...                             ...                          ...
# 777710           1 person household                  high income
# 777711           1 person household                  high income
# 777712           1 person household                  high income
# 777713           1 person household                  high income
# 777714           1 person household                  high income
#
# [777715 rows x 28 columns]

# %% [markdown]
# grouping days_birth

# %%
conditions3=[
    (new_file["DAYS_BIRTH"] < 0 ) & (new_file["DAYS_BIRTH"]>=-7300),
    (new_file["DAYS_BIRTH"] < -7300) & (new_file["DAYS_BIRTH"]>=-10950),
    (new_file["DAYS_BIRTH"] < -10950) & (new_file["DAYS_BIRTH"]>=-14600),
    (new_file["DAYS_BIRTH"] < -14600) & (new_file["DAYS_BIRTH"]>=-18250),
    (new_file["DAYS_BIRTH"] < -18250) & (new_file["DAYS_BIRTH"]>=-21900),
    (new_file["DAYS_BIRTH"] < -21900) & (new_file["DAYS_BIRTH"]>=-25201)
]

# %%
values3=["under 20ties", "under 30ties", "under 40ties", "under 50ties","under 60ties","over 60ties"]

# %%
new_file["DAYS_BIRTH_CATEGORIZED"]=np.select(conditions3,values3)
new_file
# Out:
#         Unnamed: 0_x       ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                  0  5008804           M             1                1
# 1                  1  5008804           M             1                1
# 2                  2  5008804           M             1                1
# 3                  3  5008804           M             1                1
# 4                  4  5008804           M             1                1
# ...              ...      ...         ...           ...              ...
# 777710        777710  5150337           M             0                1
# 777711        777711  5150337           M             0                1
# 777712        777712  5150337           M             0                1
# 777713        777713  5150337           M             0                1
# 777714        777714  5150337           M             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0          427500.0          Working
# 1                  0          427500.0          Working
# 2                  0          427500.0          Working
# 3                  0          427500.0          Working
# 4                  0          427500.0          Working
# ...              ...               ...              ...
# 777710             0          112500.0          Working
# 777711             0          112500.0          Working
# 777712             0          112500.0          Working
# 777713             0          112500.0          Working
# 777714             0          112500.0          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ... STATUS  \
# 0                    Higher education        Civil marriage  ...      C
# 1                    Higher education        Civil marriage  ...      C
# 2                    Higher education        Civil marriage  ...      C
# 3                    Higher education        Civil marriage  ...      C
# 4                    Higher education        Civil marriage  ...      C
# ...                               ...                   ...  ...    ...
# 777710  Secondary / secondary special  Single / not married  ...      0
# 777711  Secondary / secondary special  Single / not married  ...      2
# 777712  Secondary / secondary special  Single / not married  ...      1
# 777713  Secondary / secondary special  Single / not married  ...      0
# 777714  Secondary / secondary special  Single / not married  ...      0
#
#         Unnamed: 0_y  NUMBER_OF_RECORDS  ACTIVE  TOTAL_STATUS  GOOD_BAD  \
# 0              92938                 16       1      0.931985         1
# 1              92938                 16       1      0.931985         1
# 2              92938                 16       1      0.931985         1
# 3              92938                 16       1      0.931985         1
# 4              92938                 16       1      0.931985         1
# ...              ...                ...     ...           ...       ...
# 777710       1047002                 14       1     -0.521429         0
# 777711       1047002                 14       1     -0.521429         0
# 777712       1047002                 14       1     -0.521429         0
# 777713       1047002                 14       1     -0.521429         0
# 777714       1047002                 14       1     -0.521429         0
#
#        CNT_CHILDREN_CATEGORIZED  CNT_FAM_MEMBERS_CATEGORIZED  \
# 0                   No children                       couple
# 1                   No children                       couple
# 2                   No children                       couple
# 3                   No children                       couple
# 4                   No children                       couple
# ...                         ...                          ...
# 777710              No children           1 person household
# 777711              No children           1 person household
# 777712              No children           1 person household
# 777713              No children           1 person household
# 777714              No children           1 person household
#
#         AMT_INCOME_TOTAL_CATEGORIZED DAYS_BIRTH_CATEGORIZED
# 0                   very high income           under 40ties
# 1                   very high income           under 40ties
# 2                   very high income           under 40ties
# 3                   very high income           under 40ties
# 4                   very high income           under 40ties
# ...                              ...                    ...
# 777710                   high income           under 30ties
# 777711                   high income           under 30ties
# 777712                   high income           under 30ties
# 777713                   high income           under 30ties
# 777714                   high income           under 30ties
#
# [777715 rows x 29 columns]

# %% [markdown]
# grouping days_employed

# %%
conditions4=[
    (new_file["DAYS_EMPLOYED"] > 0),
    (new_file["DAYS_EMPLOYED"] > 0),
    (new_file["DAYS_EMPLOYED"] < 0 ) & (new_file["DAYS_EMPLOYED"]>=-1825),
    (new_file["DAYS_EMPLOYED"] < -1825) & (new_file["DAYS_EMPLOYED"]>=-3650),
    (new_file["DAYS_EMPLOYED"] < -3650) & (new_file["DAYS_EMPLOYED"]>=-5475),
    (new_file["DAYS_EMPLOYED"] < -5475),
             ]

# %%
values4=["pensioner","no working experience", "under 5 years", "under 10 years", "under 15 years", "more than 15 years"]

# %%
new_file["DAYS_EMPLOYED_CATEGORIZED"]=np.select(conditions4,values4)
new_file
# Out:
#         Unnamed: 0_x       ID CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0                  0  5008804           M             1                1
# 1                  1  5008804           M             1                1
# 2                  2  5008804           M             1                1
# 3                  3  5008804           M             1                1
# 4                  4  5008804           M             1                1
# ...              ...      ...         ...           ...              ...
# 777710        777710  5150337           M             0                1
# 777711        777711  5150337           M             0                1
# 777712        777712  5150337           M             0                1
# 777713        777713  5150337           M             0                1
# 777714        777714  5150337           M             0                1
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL NAME_INCOME_TYPE  \
# 0                  0          427500.0          Working
# 1                  0          427500.0          Working
# 2                  0          427500.0          Working
# 3                  0          427500.0          Working
# 4                  0          427500.0          Working
# ...              ...               ...              ...
# 777710             0          112500.0          Working
# 777711             0          112500.0          Working
# 777712             0          112500.0          Working
# 777713             0          112500.0          Working
# 777714             0          112500.0          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ... Unnamed: 0_y  \
# 0                    Higher education        Civil marriage  ...        92938
# 1                    Higher education        Civil marriage  ...        92938
# 2                    Higher education        Civil marriage  ...        92938
# 3                    Higher education        Civil marriage  ...        92938
# 4                    Higher education        Civil marriage  ...        92938
# ...                               ...                   ...  ...          ...
# 777710  Secondary / secondary special  Single / not married  ...      1047002
# 777711  Secondary / secondary special  Single / not married  ...      1047002
# 777712  Secondary / secondary special  Single / not married  ...      1047002
# 777713  Secondary / secondary special  Single / not married  ...      1047002
# 777714  Secondary / secondary special  Single / not married  ...      1047002
#
#         NUMBER_OF_RECORDS  ACTIVE  TOTAL_STATUS  GOOD_BAD  \
# 0                      16       1      0.931985         1
# 1                      16       1      0.931985         1
# 2                      16       1      0.931985         1
# 3                      16       1      0.931985         1
# 4                      16       1      0.931985         1
# ...                   ...     ...           ...       ...
# 777710                 14       1     -0.521429         0
# 777711                 14       1     -0.521429         0
# 777712                 14       1     -0.521429         0
# 777713                 14       1     -0.521429         0
# 777714                 14       1     -0.521429         0
#
#         CNT_CHILDREN_CATEGORIZED CNT_FAM_MEMBERS_CATEGORIZED  \
# 0                    No children                      couple
# 1                    No children                      couple
# 2                    No children                      couple
# 3                    No children                      couple
# 4                    No children                      couple
# ...                          ...                         ...
# 777710               No children          1 person household
# 777711               No children          1 person household
# 777712               No children          1 person household
# 777713               No children          1 person household
# 777714               No children          1 person household
#
#         AMT_INCOME_TOTAL_CATEGORIZED  DAYS_BIRTH_CATEGORIZED  \
# 0                   very high income            under 40ties
# 1                   very high income            under 40ties
# 2                   very high income            under 40ties
# 3                   very high income            under 40ties
# 4                   very high income            under 40ties
# ...                              ...                     ...
# 777710                   high income            under 30ties
# 777711                   high income            under 30ties
# 777712                   high income            under 30ties
# 777713                   high income            under 30ties
# 777714                   high income            under 30ties
#
#        DAYS_EMPLOYED_CATEGORIZED
# 0                 under 15 years
# 1                 under 15 years
# 2                 under 15 years
# 3                 under 15 years
# 4                 under 15 years
# ...                          ...
# 777710             under 5 years
# 777711             under 5 years
# 777712             under 5 years
# 777713             under 5 years
# 777714             under 5 years
#
# [777715 rows x 30 columns]

# %%
matrix=new_file.groupby(by=["CODE_GENDER","FLAG_OWN_CAR","FLAG_OWN_REALTY",
                     "NAME_INCOME_TYPE","NAME_HOUSING_TYPE","NAME_EDUCATION_TYPE","NAME_FAMILY_STATUS",
                     "FLAG_EMAIL","FLAG_WORK_PHONE","FLAG_PHONE","OCCUPATION_TYPE","CNT_CHILDREN_CATEGORIZED","CNT_FAM_MEMBERS_CATEGORIZED",
                    "AMT_INCOME_TOTAL_CATEGORIZED","DAYS_BIRTH_CATEGORIZED",
                    "DAYS_EMPLOYED_CATEGORIZED","GOOD_BAD"]).count()["ID"]
matrix
# Out:
# CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  NAME_INCOME_TYPE      NAME_HOUSING_TYPE  NAME_EDUCATION_TYPE            NAME_FAMILY_STATUS    FLAG_EMAIL  FLAG_WORK_PHONE  FLAG_PHONE  OCCUPATION_TYPE        CNT_CHILDREN_CATEGORIZED  CNT_FAM_MEMBERS_CATEGORIZED  AMT_INCOME_TOTAL_CATEGORIZED  DAYS_BIRTH_CATEGORIZED  DAYS_EMPLOYED_CATEGORIZED  GOOD_BAD
# F            0             0                Commercial associate  House / apartment  Higher education               Civil marriage        0           0                0           Not provided           No children               couple                       very high income              under 30ties            under 5 years              0            11
#                                                                                                                                                                                                                                                                                                under 40ties            under 10 years             1             5
#                                                                                                                                                                                    Sales staff            1 child                   2+1                          very high income              under 50ties            under 10 years             0           103
#                                                                                                                                                                                                                                                                                                                                                   1            60
#                                                                                                                                                                        1           Core staff             No children               couple                       very high income              0                       under 15 years             1             9
#                                                                                                                                                                                                                                                                                                                                                              ...
# M            1             1                Working               With parents       Secondary / secondary special  Single / not married  0           0                0           Drivers                No children               1 person household           high income                   under 30ties            under 5 years              1             3
#                                                                                                                                                                        1           Drivers                No children               1 person household           very high income              under 50ties            under 10 years             0            77
#                                                                                                                                                       1                0           Drivers                No children               1 person household           very high income              under 40ties            under 5 years              1            49
#                                                                                                                                                                        1           High skill tech staff  No children               1 person household           high income                   under 30ties            under 10 years             0            11
#                                                                                                                                                                                                                                                                                                                                                   1           105
# Name: ID, Length: 11592, dtype: int64

# %%
matrix_percentage=((new_file.groupby(by=["CODE_GENDER","FLAG_OWN_CAR","FLAG_OWN_REALTY",
                     "NAME_INCOME_TYPE","NAME_HOUSING_TYPE","NAME_EDUCATION_TYPE","NAME_FAMILY_STATUS",
                     "FLAG_EMAIL","FLAG_WORK_PHONE","FLAG_PHONE","OCCUPATION_TYPE","CNT_CHILDREN_CATEGORIZED","CNT_FAM_MEMBERS_CATEGORIZED",
                    "AMT_INCOME_TOTAL_CATEGORIZED","DAYS_BIRTH_CATEGORIZED",
                    "DAYS_EMPLOYED_CATEGORIZED","GOOD_BAD"]).count()["ID"])/new_file.count()["ID"])*100
matrix_percentage
# Out:
# CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  NAME_INCOME_TYPE      NAME_HOUSING_TYPE  NAME_EDUCATION_TYPE            NAME_FAMILY_STATUS    FLAG_EMAIL  FLAG_WORK_PHONE  FLAG_PHONE  OCCUPATION_TYPE        CNT_CHILDREN_CATEGORIZED  CNT_FAM_MEMBERS_CATEGORIZED  AMT_INCOME_TOTAL_CATEGORIZED  DAYS_BIRTH_CATEGORIZED  DAYS_EMPLOYED_CATEGORIZED  GOOD_BAD
# F            0             0                Commercial associate  House / apartment  Higher education               Civil marriage        0           0                0           Not provided           No children               couple                       very high income              under 30ties            under 5 years              0           0.001414
#                                                                                                                                                                                                                                                                                                under 40ties            under 10 years             1           0.000643
#                                                                                                                                                                                    Sales staff            1 child                   2+1                          very high income              under 50ties            under 10 years             0           0.013244
#                                                                                                                                                                                                                                                                                                                                                   1           0.007715
#                                                                                                                                                                        1           Core staff             No children               couple                       very high income              0                       under 15 years             1           0.001157
#                                                                                                                                                                                                                                                                                                                                                                 ...
# M            1             1                Working               With parents       Secondary / secondary special  Single / not married  0           0                0           Drivers                No children               1 person household           high income                   under 30ties            under 5 years              1           0.000386
#                                                                                                                                                                        1           Drivers                No children               1 person household           very high income              under 50ties            under 10 years             0           0.009901
#                                                                                                                                                       1                0           Drivers                No children               1 person household           very high income              under 40ties            under 5 years              1           0.006301
#                                                                                                                                                                        1           High skill tech staff  No children               1 person household           high income                   under 30ties            under 10 years             0           0.001414
#                                                                                                                                                                                                                                                                                                                                                   1           0.013501
# Name: ID, Length: 11592, dtype: float64

# %%
matrix_percentage.to_csv("/Users/joannaborowa/Desktop/matrix_percentage.csv")

# %%
matrix["percent"]=matrix.value_counts(normalize=True).mul(100).round(1).astype("str")+ "%"

# %%
matrix
# Out:
# CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  NAME_INCOME_TYPE      NAME_HOUSING_TYPE  NAME_EDUCATION_TYPE            NAME_FAMILY_STATUS    FLAG_EMAIL  FLAG_WORK_PHONE  FLAG_PHONE  OCCUPATION_TYPE        CNT_CHILDREN_CATEGORIZED  CNT_FAM_MEMBERS_CATEGORIZED  AMT_INCOME_TOTAL_CATEGORIZED  DAYS_BIRTH_CATEGORIZED  DAYS_EMPLOYED_CATEGORIZED  GOOD_BAD
# F            0             0                Commercial associate  House / apartment  Higher education               Civil marriage        0           0                0           Not provided           No children               couple                       very high income              under 30ties            under 5 years              0                                                          11
#                                                                                                                                                                                                                                                                                                under 40ties            under 10 years             1                                                           5
#                                                                                                                                                                                    Sales staff            1 child                   2+1                          very high income              under 50ties            under 10 years             0                                                         103
#                                                                                                                                                                                                                                                                                                                                                   1                                                          60
#                                                                                                                                                                        1           Core staff             No children               couple                       very high income              0                       under 15 years             1                                                           9
#                                                                                                                                                                                                                                                                                                                                                                                     ...
# M            1             1                Working               With parents       Secondary / secondary special  Single / not married  0           0                1           Drivers                No children               1 person household           very high income              under 50ties            under 10 years             0                                                          77
#                                                                                                                                                       1                0           Drivers                No children               1 person household           very high income              under 40ties            under 5 years              1                                                          49
#                                                                                                                                                                        1           High skill tech staff  No children               1 person household           high income                   under 30ties            under 10 years             0                                                          11
#                                                                                                                                                                                                                                                                                                                                                   1                                                         105
# percent                                                                                                                                                                                                                                                                                                                                                       12      1.9%
# 8       1.9%
# 13      1.8%
# 10     ...
# Name: ID, Length: 11593, dtype: object

# %%
matrix.to_csv("/Users/joannaborowa/Desktop/matrix.csv")
